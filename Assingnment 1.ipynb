# %% [markdown]
# # A RAMANAGIRI
# # RA2011003010528

# %%
import pandas as pd 
s = pd.read_csv('/content/cristiano_vs_messi.csv')
s.head()
# Out:
#     player                      comp         round        date venue  \
# 0  ronaldo                  Liga NOS             6   10/7/2002     H
# 1  ronaldo                  Liga NOS             6   10/7/2002     H
# 2  ronaldo                  Liga NOS             8  10/26/2002     A
# 3  ronaldo  Taça de Portugal Placard  Fourth Round  11/24/2002     H
# 4  ronaldo  Taça de Portugal Placard   Fifth Round  12/18/2002     H
#
#               opp  pos  min              type        assisted
# 0     Moreirense    RW  34'               NaN             NaN
# 1     Moreirense   NaN  90'               NaN             NaN
# 2        Boavista  NaN  88'               NaN  Carlos Martins
# 3       Estarreja  NaN  67'  Left-footed shot    César Prates
# 4  Oliv. Hospital  NaN  13'               NaN             NaN

# %%
s.head(15)
# Out:
#      player                      comp         round        date venue  \
# 0   ronaldo                  Liga NOS             6   10/7/2002     H
# 1   ronaldo                  Liga NOS             6   10/7/2002     H
# 2   ronaldo                  Liga NOS             8  10/26/2002     A
# 3   ronaldo  Taça de Portugal Placard  Fourth Round  11/24/2002     H
# 4   ronaldo  Taça de Portugal Placard   Fifth Round  12/18/2002     H
# 5   ronaldo            Premier League            11   11/1/2003     H
# 6   ronaldo                    FA Cup   Fifth Round   2/14/2004     H
# 7   ronaldo            Premier League            29   3/20/2004     H
# 8   ronaldo            Premier League            32   4/10/2004     A
# 9   ronaldo            Premier League            38   5/15/2004     A
# 10  ronaldo                    FA Cup         Final   5/22/2004     H
# 11  ronaldo            Premier League            16   12/4/2004     H
# ...

# %%
s.tail()
# Out:
#      player    comp round        date venue                opp  pos    min  \
# 1295  messi     NaN   NaN         NaN   NaN                NaN  NaN    82'
# 1296  messi  LaLiga    11  11/29/2020     H       CA Osasuna    RW     73'
# 1297  messi  LaLiga    13  12/13/2020     H          Levante    CF     76'
# 1298  messi  LaLiga    14  12/19/2020     H         Valencia    CF   45'+4
# 1299  messi  LaLiga    15  12/22/2020     A  Real Valladolid    SS     65'
#
#                   type         assisted
# 1295  Left-footed shot    Sergi Roberto
# 1296  Left-footed shot          Trincão
# 1297  Left-footed shot  Frenkie de Jong
# 1298            Header              NaN
# 1299  Left-footed shot            Pedri

# %%
s.columns
# Out:
# Index(['player', 'comp', 'round', 'date', 'venue', 'opp', 'pos', 'min', 'type',
#        'assisted'],
#       dtype='object')

# %%
s.describe()
# Out:
#          player    comp        round       date venue           opp  pos  \
# count      1300     846          846        846   846           846  793
# unique        2      15           53        745     2           182   10
# top     ronaldo  LaLiga  Group Stage  10/7/2002     H  Sevilla FC     CF
# freq        656     468           91          2   480            31  246
#
#          min              type     assisted
# count   1300              1281          874
# unique   107                12          132
# top      90'  Left-footed shot  Luis Suárez
# freq      29               496           48

# %%
print(s.isnull().sum())
# Out:
# player        0
# comp        454
# round       454
# date        454
# venue       454
# opp         454
# pos         507
# min           0
# type         19
# assisted    426
# dtype: int64

# %%
s.comp=s.comp.fillna("unknown")
print(s.isnull().sum())
# Out:
# player        0
# comp          0
# round       454
# date        454
# venue       454
# opp         454
# pos         507
# min           0
# type         19
# assisted    426
# dtype: int64

# %%
s.date=s.date.fillna(0)
print(s.isnull().sum())
# Out:
# player        0
# comp          0
# round       454
# date          0
# venue       454
# opp         454
# pos         507
# min           0
# type         19
# assisted    426
# dtype: int64

# %%
s.venue=s.venue.fillna(0)
print(s.isnull().sum())
# Out:
# player        0
# comp          0
# round       454
# date          0
# venue         0
# opp         454
# pos         507
# min           0
# type         19
# assisted    426
# dtype: int64

# %%
s.opp=s.opp.fillna(0)
print(s.isnull().sum())
# Out:
# player        0
# comp          0
# round       454
# date          0
# venue         0
# opp           0
# pos         507
# min           0
# type         19
# assisted    426
# dtype: int64

# %%
s.pos=s.pos.fillna(0)
print(s.isnull().sum())
# Out:
# player        0
# comp          0
# round       454
# date          0
# venue         0
# opp           0
# pos           0
# min           0
# type         19
# assisted    426
# dtype: int64

# %%
s.type=s.type.fillna(0)
print(s.isnull().sum())
# Out:
# player        0
# comp          0
# round       454
# date          0
# venue         0
# opp           0
# pos           0
# min           0
# type          0
# assisted    426
# dtype: int64

# %%
s.assisted=s.assisted.fillna(0)
print(s.isnull().sum())
# Out:
# player        0
# comp          0
# round       454
# date          0
# venue         0
# opp           0
# pos           0
# min           0
# type          0
# assisted      0
# dtype: int64

# %%
s.head(25)
# Out:
#      player                         comp         round        date venue  \
# 0   ronaldo                     Liga NOS             6   10/7/2002     H
# 1   ronaldo                     Liga NOS             6   10/7/2002     H
# 2   ronaldo                     Liga NOS             8  10/26/2002     A
# 3   ronaldo     Taça de Portugal Placard  Fourth Round  11/24/2002     H
# 4   ronaldo     Taça de Portugal Placard   Fifth Round  12/18/2002     H
# 5   ronaldo               Premier League            11   11/1/2003     H
# 6   ronaldo                       FA Cup   Fifth Round   2/14/2004     H
# 7   ronaldo               Premier League            29   3/20/2004     H
# 8   ronaldo               Premier League            32   4/10/2004     A
# 9   ronaldo               Premier League            38   5/15/2004     A
# 10  ronaldo                       FA Cup         Final   5/22/2004     H
# 11  ronaldo               Premier League            16   12/4/2004     H
# ...
